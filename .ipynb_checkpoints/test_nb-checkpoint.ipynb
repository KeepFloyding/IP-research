# %% [markdown]
# # Testing code
#
# Run the Jupyter notebook below to test if the packages have been correctly installed.
#
# The test includes importing some data, performing a PCA analysis and performing a scatter plot.
# If everything has been installed correctly, there should be no errors.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

# Do some PCA analysis
X_pca = PCA().fit_transform(iris.data)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, edgecolor='k', s=40)
